# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Health Inequality Dataset
#
# This data was taken from this study https://healthinequality.org/ that aimed to measure and shed light on racial and other inequalities in healthcare, and "uses big data to measure differences in life expectancy by income across areas and identify strategies to improve health outcomes for low-income Americans."
#
# Find the data dictionary for the inequality file [here](https://healthinequality.org/dl/health_ineq_online_table_11_readme.pdf)
#
# Find the data dictionary for the county file [here](https://healthinequality.org/dl/health_ineq_online_table_12_readme.pdf)

# %% [markdown]
# ### Import the Data

# %%
import pandas as pd
health_inequality = pd.read_csv("https://raw.githubusercontent.com/pballent/hia_255_healthinequality/main/health_inequality_dataset.csv")
health_inequality
# Out:
#         cty county_name  cty_pop2000     cz       cz_name  cz_pop2000  \
# 0      1001     Autauga        43671  11101    Montgomery      367927
# 1      1003     Baldwin       140415  11001        Mobile      599405
# 2      1005     Barbour        29038  10301       Eufaula       61458
# 3      1009      Blount        51024  10700    Birmingham     1038182
# 4      1015     Calhoun       112249   9600      LaGrange      457299
# ...     ...         ...          ...    ...           ...         ...
# 1554  56021     Laramie        81607  27702      Cheyenne       95526
# 1555  56025     Natrona        66533  34603        Casper       78585
# 1556  56029        Park        25786  34301          Cody       37247
# 1557  56033    Sheridan        26560  34304      Sheridan       46306
# 1558  56037  Sweetwater        37613  36404  Rock Springs       80730
#
#      statename  state_id stateabbrv  le_agg_q1_F  ...  cs_educ_ba  \
# 0      Alabama         1         AL    79.775871  ...   18.000000
# 1      Alabama         1         AL    82.847725  ...   23.100000
# 2      Alabama         1         AL    83.149445  ...   10.900000
# 3      Alabama         1         AL    81.088120  ...    9.600000
# 4      Alabama         1         AL    79.486259  ...   15.200000
# ...        ...       ...        ...          ...  ...         ...
# 1554   Wyoming        56         WY    80.849884  ...   23.400000
# 1555   Wyoming        56         WY    79.617317  ...   20.000000
# 1556   Wyoming        56         WY    82.349632  ...   23.700001
# 1557   Wyoming        56         WY    81.758583  ...   22.400000
# 1558   Wyoming        56         WY    81.354218  ...   17.000000
#
#       exercise_any_q1  cs_labforce    tuition  diab_eyeexam_10  gradrate_r  \
# 0            0.500000     0.651493        NaN        72.419628         NaN
# 1            0.599432     0.598249  2055.6699        64.047822   -0.247166
# 2            0.542857     0.480174        NaN        67.556468         NaN
# 3            0.565217     0.605729        NaN        68.155340         NaN
# 4            0.544304     0.578343  2506.3513        62.862669   -0.034474
# ...               ...          ...        ...              ...         ...
# 1554         0.677233     0.663209  1128.0000        66.319773   -0.226124
# 1555         0.675015     0.682550  1248.0000        66.987620   -0.115988
# 1556         0.661082     0.640475  1128.0000        78.021978   -0.093242
# 1557         0.673342     0.661194  1128.0000        66.043614   -0.129339
# 1558         0.622924     0.705721  1128.0000        57.586207    0.158455
#
#       cur_smoke_q4  crime_total  poor_share     cbsa
# 0         0.133333     0.009353    0.109228  33860.0
# 1         0.176991     0.007371    0.101471  19300.0
# 2         0.111111     0.007748    0.267998      NaN
# 3         0.166667     0.002019    0.117428  13820.0
# 4         0.182482     0.008780    0.161113  11500.0
# ...            ...          ...         ...      ...
# 1554      0.135569     0.008480    0.090975  16940.0
# 1555      0.135472     0.009649    0.118365  16220.0
# 1556      0.075881     0.004305    0.127367      NaN
# 1557      0.107623     0.006739    0.107487  43260.0
# 1558      0.178484     0.011671    0.077714  40540.0
#
# [1559 rows x 116 columns]

# %%
list(health_inequality.columns)
# Out:
# ['cty',
#  'county_name',
#  'cty_pop2000',
#  'cz',
#  'cz_name',
#  'cz_pop2000',
#  'statename',
#  'state_id',
#  'stateabbrv',
#  'le_agg_q1_F',
#  'le_raceadj_q1_F',
#  'le_agg_q2_F',
#  'le_raceadj_q2_F',
#  'le_agg_q3_F',
#  'le_raceadj_q3_F',
#  'le_agg_q4_F',
#  'le_raceadj_q4_F',
#  'le_agg_q1_M',
#  'le_raceadj_q1_M',
#  'le_agg_q2_M',
#  'le_raceadj_q2_M',
#  'le_agg_q3_M',
#  'le_raceadj_q3_M',
#  'le_agg_q4_M',
#  'le_raceadj_q4_M',
#  'sd_le_agg_q1_F',
#  'sd_le_raceadj_q1_F',
#  'sd_le_agg_q2_F',
#  'sd_le_raceadj_q2_F',
#  'sd_le_agg_q3_F',
#  'sd_le_raceadj_q3_F',
#  'sd_le_agg_q4_F',
#  'sd_le_raceadj_q4_F',
#  'sd_le_agg_q1_M',
#  'sd_le_raceadj_q1_M',
#  'sd_le_agg_q2_M',
#  'sd_le_raceadj_q2_M',
#  'sd_le_agg_q3_M',
#  'sd_le_raceadj_q3_M',
#  'sd_le_agg_q4_M',
#  'sd_le_raceadj_q4_M',
#  'count_q1_F',
#  'count_q2_F',
#  'count_q3_F',
#  'count_q4_F',
#  'count_q1_M',
#  'count_q2_M',
#  'count_q3_M',
#  'count_q4_M',
#  'exercise_any_q3',
#  'intersects_msa',
#  'puninsured2010',
#  'score_r',
#  'diab_hemotest_10',
#  'ccd_pup_tch_ratio',
#  'exercise_any_q4',
#  'cs_race_theil_2000',
#  'gini99',
#  'subcty_exp_pc',
#  'adjmortmeas_amiall30day',
#  'mig_outflow',
#  'median_house_value',
#  'pop_d_2000_1980',
#  'frac_middleclass',
#  'cs00_seg_inc',
#  'ccd_exp_tot',
#  'cs_fam_wkidsinglemom',
#  'primcarevis_10',
#  'reimb_penroll_adj10',
#  'adjmortmeas_chfall30day',
#  'pop_density',
#  'unemp_rate',
#  'bmi_obese_q2',
#  'mort_30day_hosp_z',
#  'exercise_any_q2',
#  'diab_lipids_10',
#  'lf_d_2000_1980',
#  'inc_share_1perc',
#  'adjmortmeas_pnall30day',
#  'cbsa_name',
#  'rel_tot',
#  'cs_elf_ind_man',
#  'frac_traveltime_lt15',
#  'cur_smoke_q3',
#  'scap_ski90pcm',
#  'cur_smoke_q2',
#  'mammogram_10',
#  'cs00_seg_inc_aff75',
#  'e_rank_b',
#  'tax_st_diff_top20',
#  'csa_name',
#  'cs_frac_black',
#  'mig_inflow',
#  'cs00_seg_inc_pov25',
#  'bmi_obese_q3',
#  'amb_disch_per1000_10',
#  'bmi_obese_q1',
#  'cs_frac_hisp',
#  'med_prev_qual_z',
#  'cs_born_foreign',
#  'csa',
#  'hhinc00',
#  'dropout_r',
#  'cur_smoke_q1',
#  'bmi_obese_q4',
#  'taxrate',
#  'cs_educ_ba',
#  'exercise_any_q1',
#  'cs_labforce',
#  'tuition',
#  'diab_eyeexam_10',
#  'gradrate_r',
#  'cur_smoke_q4',
#  'crime_total',
#  'poor_share',
#  'cbsa']

# %%
health_inequality.head(50)
# Out:
#      cty           county_name  cty_pop2000     cz     cz_name  cz_pop2000  \
# 0   1001               Autauga        43671  11101  Montgomery      367927
# 1   1003               Baldwin       140415  11001      Mobile      599405
# 2   1005               Barbour        29038  10301     Eufaula       61458
# 3   1009                Blount        51024  10700  Birmingham     1038182
# 4   1015               Calhoun       112249   9600    LaGrange      457299
# 5   1017              Chambers        36583   9600    LaGrange      457299
# 6   1021               Chilton        39593  10700  Birmingham     1038182
# 7   1025                Clarke        27867  11001      Mobile      599405
# 8   1031                Coffee        43615  10302      Dothan      223605
# 9   1033               Colbert        54984   6200    Florence      230941
# 10  1039             Covington        37631  11102        Troy       80901
# 11  1043               Cullman        77483  10700  Birmingham     1038182
# 12  1045                  Dale        49129  10302      Dothan      223605
# 13  1047                Dallas        46365  10801  Tuscaloosa      261112
# 14  1049                DeKalb        64452   6100     Gadsden      304068
# 15  1051                Elmore        65874  11101  Montgomery      367927
# 16  1053              Escambia        38440  11002      Atmore       76853
# 17  1055                Etowah       103459   6100     Gadsden      304068
# 18  1059              Franklin        31223   6200    Florence      230941
# 19  1061                Geneva        25764  10302      Dothan      223605
# 20  1069               Houston        88787  10302      Dothan      223605
# 21  1071               Jackson        53926   6100     Gadsden      304068
# 22  1073             Jefferson       662047  10700  Birmingham     1038182
# 23  1077            Lauderdale        87966   6200    Florence      230941
# 24  1079              Lawrence        34803   6000  Huntsville      519583
# 25  1081                   Lee       115092   9800      Auburn      150911
# 26  1083             Limestone        65676   6000  Huntsville      519583
# 27  1089               Madison       276700   6000  Huntsville      519583
# 28  1093                Marion        31214  10600      Jasper      161169
# 29  1095              Marshall        82231   6100     Gadsden      304068
# 30  1097                Mobile       399843  11001      Mobile      599405
# 31  1101            Montgomery       223510  11101  Montgomery      367927
# 32  1103                Morgan       111064   6000  Huntsville      519583
# 33  1109                  Pike        29605  11102        Troy       80901
# 34  1113               Russell        49756   9701    Columbus      303656
# 35  1115              St Clair        64742  10700  Birmingham     1038182
# 36  1117                Shelby       143293  10700  Birmingham     1038182
# 37  1121             Talladega        80321   9500   Talladega      148252
# 38  1123            Tallapoosa        41475   9500   Talladega      148252
# 39  1125            Tuscaloosa       164875  10801  Tuscaloosa      261112
# 40  1127                Walker        70713  10600      Jasper      161169
# 41  2020             Anchorage       260283  34102   Anchorage      369296
# 42  2090  Fairbanks North Star        82840  34115   Fairbanks       97458
# 43  2110                Juneau        30711  34109      Juneau       37347
# 44  2122       Kenai Peninsula        49691  34102   Anchorage      369296
# 45  2170     Matanuska-Susitna        59322  34102   Anchorage      369296
# 46  4001                Apache        69423  35500      Gallup      241691
# 47  4003               Cochise       117755  35100      Tucson      999882
# 48  4005              Coconino       116320  35401   Flagstaff      289883
# 49  4007                  Gila        51335  35001     Phoenix     3303211
#
#    statename  state_id stateabbrv  le_agg_q1_F  ...  cs_educ_ba  \
# 0    Alabama         1         AL    79.775871  ...   18.000000
# 1    Alabama         1         AL    82.847725  ...   23.100000
# 2    Alabama         1         AL    83.149445  ...   10.900000
# 3    Alabama         1         AL    81.088120  ...    9.600000
# 4    Alabama         1         AL    79.486259  ...   15.200000
# 5    Alabama         1         AL    80.310249  ...    9.500000
# 6    Alabama         1         AL    81.830360  ...    9.900000
# 7    Alabama         1         AL    83.096024  ...   12.100000
# 8    Alabama         1         AL    81.095596  ...   19.299999
# 9    Alabama         1         AL    82.128868  ...   14.100000
# 10   Alabama         1         AL    82.331375  ...   12.200000
# 11   Alabama         1         AL    82.028610  ...   11.900000
# 12   Alabama         1         AL    81.102219  ...   14.000000
# 13   Alabama         1         AL    80.374802  ...   13.900000
# 14   Alabama         1         AL    82.484261  ...    8.300000
# 15   Alabama         1         AL    81.093826  ...   16.600000
# 16   Alabama         1         AL    81.194901  ...   10.600000
# 17   Alabama         1         AL    80.470299  ...   13.400000
# 18   Alabama         1         AL    81.656380  ...    9.700000
# 19   Alabama         1         AL    83.223495  ...    8.700000
# 20   Alabama         1         AL    81.841095  ...   18.400000
# 21   Alabama         1         AL    81.367775  ...   10.400000
# 22   Alabama         1         AL    80.212410  ...   24.600000
# 23   Alabama         1         AL    82.060234  ...   18.500000
# 24   Alabama         1         AL    81.697388  ...    7.500000
# 25   Alabama         1         AL    81.123238  ...   27.900000
# 26   Alabama         1         AL    81.583847  ...   16.900000
# 27   Alabama         1         AL    80.687965  ...   34.299999
# 28   Alabama         1         AL    82.170341  ...    8.000000
# 29   Alabama         1         AL    81.258301  ...   13.900000
# 30   Alabama         1         AL    81.303596  ...   18.600000
# 31   Alabama         1         AL    80.189369  ...   28.500000
# 32   Alabama         1         AL    80.982254  ...   18.400000
# 33   Alabama         1         AL    81.474281  ...   18.400000
# 34   Alabama         1         AL    80.373734  ...    9.700000
# 35   Alabama         1         AL    81.117645  ...   11.100000
# 36   Alabama         1         AL    81.815582  ...   36.799999
# 37   Alabama         1         AL    80.767448  ...   11.200000
# 38   Alabama         1         AL    82.000969  ...   14.100000
# 39   Alabama         1         AL    80.700562  ...   24.000000
# 40   Alabama         1         AL    80.929367  ...    9.100000
# 41    Alaska         2         AK    82.065903  ...   28.900000
# 42    Alaska         2         AK    82.673996  ...   27.000000
# 43    Alaska         2         AK    85.048470  ...   36.000000
# 44    Alaska         2         AK    83.519005  ...   20.299999
# 45    Alaska         2         AK    82.070107  ...   18.299999
# 46   Arizona         4         AZ    84.895821  ...   11.300000
# 47   Arizona         4         AZ    82.895622  ...   18.799999
# 48   Arizona         4         AZ    83.866592  ...   29.900000
# 49   Arizona         4         AZ    81.384773  ...   13.900000
#
#     exercise_any_q1  cs_labforce    tuition  diab_eyeexam_10  gradrate_r  \
# 0          0.500000     0.651493        NaN        72.419628         NaN
# 1          0.599432     0.598249  2055.6699        64.047822   -0.247166
# 2          0.542857     0.480174        NaN        67.556468         NaN
# 3          0.565217     0.605729        NaN        68.155340         NaN
# 4          0.544304     0.578343  2506.3513        62.862669   -0.034474
# 5          0.666667     0.585549        NaN        58.539765         NaN
# 6          0.481481     0.597152        NaN        69.419643         NaN
# 7          0.500000     0.542532        NaN        54.264973         NaN
# 8          0.607843     0.595883  1560.0000        63.449940   -0.030344
# 9          0.500000     0.561961  1440.0000        58.282209   -0.254089
# 10         0.627907     0.559180  1516.0396        61.778291   -0.127115
# 11         0.635514     0.601862  1200.0000        67.436823    0.109052
# 12         0.636364     0.622726        NaN        67.360208   -0.158576
# 13         0.554795     0.499755  3190.3149        61.047254   -0.122716
# 14         0.570000     0.615022  1320.0000        57.434944    0.087986
# 15         0.485714     0.590097        NaN        71.168582         NaN
# 16         0.500000     0.520314  1560.0000        57.990315    0.035239
# 17         0.524456     0.565547  1560.0000        63.891675   -0.160966
# 18         0.457143     0.565958        NaN        59.459459         NaN
# 19         0.382353     0.579946        NaN        69.846154         NaN
# 20         0.554455     0.623604  1588.8889        70.382883         NaN
# 21         0.500000     0.620267        NaN        55.815900         NaN
# 22         0.565058     0.615210  5698.8433        67.072721   -0.029533
# 23         0.580645     0.589418  2346.3972        59.155733    0.007794
# 24         0.636364     0.585676        NaN        58.631922         NaN
# 25         0.668000     0.620013  3050.0000        61.675824    0.292959
# 26         0.419355     0.608455        NaN        63.776337   -0.294866
# 27         0.617849     0.675711  3735.8979        64.680266   -0.037664
# 28         0.479167     0.561300        NaN        65.454545         NaN
# 29         0.511416     0.605834  1320.0000        56.894410   -0.112873
# 30         0.561828     0.593920  6005.2324        62.731997    0.017665
# 31         0.563071     0.613377  3753.1160        70.290493   -0.065947
# 32         0.590062     0.622360  1560.0000        64.680442         NaN
# 33         0.400000     0.606161  2850.0000        70.600858   -0.004354
# 34         0.571429     0.571037  1560.0000        64.725644   -0.245007
# 35         0.613861     0.589793        NaN        67.934783         NaN
# 36         0.610811     0.703458  5424.0420        67.878387    0.019796
# 37         0.517391     0.552300  5666.0000        64.705882   -0.158146
# 38         0.660714     0.566564  1560.0000        61.772487   -0.123396
# 39         0.585321     0.607448  2998.5896        67.416633    0.151695
# 40         0.512195     0.532729  1560.0000        58.818098   -0.205446
# 41              NaN     0.743586  2786.2920        56.717949   -0.128709
# 42              NaN     0.742486  2460.0000        63.527397   -0.109444
# 43              NaN     0.754991  2460.0000        60.869565   -0.149139
# 44              NaN     0.628477        NaN        57.046980         NaN
# 45              NaN     0.660883        NaN        55.798090         NaN
# 46         0.624625     0.461190   600.0000        72.986248   -0.243933
# 47         0.658065     0.563711   744.0000        66.072490   -0.260711
# 48         0.730769     0.686250  2249.1240        60.311284    0.089306
# 49         0.619469     0.500902        NaN        66.972477         NaN
#
#     cur_smoke_q4  crime_total  poor_share     cbsa
# 0       0.133333     0.009353    0.109228  33860.0
# 1       0.176991     0.007371    0.101471  19300.0
# 2       0.111111     0.007748    0.267998      NaN
# 3       0.166667     0.002019    0.117428  13820.0
# 4       0.182482     0.008780    0.161113  11500.0
# 5       0.375000     0.006943    0.170360  46740.0
# 6       0.222222     0.005304    0.157023  13820.0
# 7       0.000000     0.007392    0.225882      NaN
# 8       0.171429     0.007260    0.146959  21460.0
# 9       0.190476     0.002819    0.139600  22520.0
# 10      0.000000     0.005820    0.184497      NaN
# 11      0.255814     0.004790    0.129992  18980.0
# 12      0.208333     0.005777    0.150935  37120.0
# 13      0.041667     0.007161    0.310549  42820.0
# 14      0.125000     0.004856    0.153910      NaN
# 15      0.172414     0.006214    0.102439  33860.0
# 16      0.214286     0.008273    0.208696      NaN
# 17      0.144578     0.006401    0.156980  23460.0
# 18      0.000000     0.004484    0.188852      NaN
# 19      0.000000     0.003998    0.196186  20020.0
# 20      0.062500     0.008777    0.149990  20020.0
# 21      0.250000     0.004543    0.136745  42460.0
# 22      0.132775     0.008594    0.147730  13820.0
# 23      0.108434     0.005525    0.144257  22520.0
# 24      0.142857     0.002902    0.152513  19460.0
# 25      0.127451     0.005412    0.218119  12220.0
# 26      0.080000     0.006351    0.123461  26620.0
# 27      0.127273     0.006683    0.105451  26620.0
# 28      0.076923     0.006734    0.156376      NaN
# 29      0.218750     0.008033    0.146617  10700.0
# 30      0.149871     0.007761    0.185073  33660.0
# 31      0.156923     0.005494    0.173401  33860.0
# 32      0.208791     0.007243    0.122912  19460.0
# 33      0.100000     0.007364    0.230666  45980.0
# 34      0.250000     0.009587    0.199028  17980.0
# 35      0.130435     0.004960    0.120762  13820.0
# 36      0.138636     0.004598    0.063136  13820.0
# 37      0.137931     0.006467    0.176147  45180.0
# 38      0.187500     0.007259    0.165589      NaN
# 39      0.118971     0.009141    0.170210  46220.0
# 40      0.211538     0.005445    0.164987  13820.0
# 41           NaN     0.012214    0.073472  11260.0
# 42           NaN     0.013933    0.077814  21820.0
# 43           NaN     0.014522    0.059669  27940.0
# 44           NaN     0.009627    0.100409      NaN
# 45           NaN     0.047191    0.110063  11260.0
# 46      0.105263     0.003558    0.378203      NaN
# 47      0.147132     0.010182    0.176746  43420.0
# 48      0.067797     0.012430    0.182258  22380.0
# 49      0.082192     0.013344    0.174117  37740.0
#
# [50 rows x 116 columns]

# %%
hi_sub = health_inequality[[
 'statename',
 'state_id', 
 "le_agg_q1_F",
 "le_agg_q1_M",
"le_agg_q4_F",
 "le_agg_q4_M"]].copy()

# %%
mean_by_state = hi_sub.groupby("statename").mean().copy()

# %%
mean_by_state.sort_values("le_agg_q4_M", ascending=False)
# Out:
#                       state_id  le_agg_q1_F  le_agg_q1_M  le_agg_q4_F  \
# statename
# North Dakota                38    82.847876    76.387524    88.140584
# Utah                        49    82.883244    77.837937    88.684213
# District Of Columbia        11    80.295586    74.652733    87.841988
# Colorado                     8    83.541477    78.726500    88.181095
# Montana                     30    83.011748    78.104045    87.788405
# Wyoming                     56    80.643085    75.656905    87.077177
# Maine                       23    82.892255    77.457387    87.975133
# Washington                  53    82.793873    78.056068    87.957006
# New Hampshire               33    81.952760    76.631449    88.145924
# Rhode Island                44    82.848993    76.890547    88.540890
# Massachusetts               25    83.204418    78.068869    88.008162
# Minnesota                   27    82.640712    77.422610    88.250715
# Idaho                       16    82.436096    77.597249    87.388150
# South Dakota                46    81.484911    76.019098    87.478976
# Connecticut                  9    82.344994    77.022887    87.900054
# Oregon                      41    82.322293    77.504059    87.180667
# Vermont                     50    82.452098    77.815965    88.068088
# California                   6    83.476607    79.121338    87.692413
# Wisconsin                   55    81.815948    76.493661    87.950532
# Hawaii                      15    83.903932    78.550591    87.506117
# New York                    36    82.209037    77.009202    87.774059
# Alaska                       2    83.075496    77.228113    87.680277
# Delaware                    10    81.080470    74.882937    87.429204
# Virginia                    51    81.679676    75.499305    87.337673
# Michigan                    26    81.089708    75.734163    87.453069
# Illinois                    17    80.553579    75.102632    87.014403
# Maryland                    24    80.962609    75.865715    87.514751
# Pennsylvania                42    82.001934    75.892430    87.618915
# Iowa                        19    81.137852    75.727905    88.097928
# New Mexico                  35    82.961122    77.713033    87.097772
# Florida                     12    82.283902    76.387572    87.426499
# Kansas                      20    80.634476    75.182556    87.777776
# New Jersey                  34    82.160076    76.989181    87.309592
# Missouri                    29    80.883683    75.302596    87.696465
# North Carolina              37    81.515087    75.138827    87.244289
# Georgia                     13    81.343714    74.731366    86.705830
# Kentucky                    21    80.737902    74.708802    86.125666
# Ohio                        39    81.157319    75.120346    86.965515
# Arizona                      4    82.699078    77.703299    86.969774
# Nebraska                    31    81.969639    76.178203    87.984153
# Texas                       48    81.692282    76.293988    87.126952
# Tennessee                   47    81.098563    74.720734    87.056002
# Indiana                     18    80.648750    74.389632    86.866789
# South Carolina              45    81.320248    74.498840    87.002157
# Arkansas                     5    80.271103    74.686547    87.137135
# Oklahoma                    40    80.098450    74.936102    85.775494
# Alabama                      1    81.376246    74.275202    86.446474
# Nevada                      32    80.829059    75.684498    86.333426
# Louisiana                   22    81.057198    74.821830    86.568116
# West Virginia               54    81.029429    75.383581    86.638577
# Mississippi                 28    81.093386    74.621735    86.617115
#
#                       le_agg_q4_M
# statename
# North Dakota            86.850777
# Utah                    86.509413
# District Of Columbia    86.448700
# Colorado                86.341647
# Montana                 85.907150
# Wyoming                 85.866862
# Maine                   85.864396
# Washington              85.804263
# New Hampshire           85.800576
# Rhode Island            85.729367
# Massachusetts           85.714502
# Minnesota               85.708965
# Idaho                   85.680106
# South Dakota            85.617635
# Connecticut             85.588213
# Oregon                  85.556685
# Vermont                 85.469197
# California              85.393121
# Wisconsin               85.295877
# Hawaii                  85.224909
# New York                85.122234
# Alaska                  84.988467
# Delaware                84.927526
# Virginia                84.916303
# Michigan                84.823941
# Illinois                84.786239
# Maryland                84.784689
# Pennsylvania            84.773430
# Iowa                    84.743382
# New Mexico              84.682654
# Florida                 84.636940
# Kansas                  84.614300
# New Jersey              84.576237
# Missouri                84.517417
# North Carolina          84.435152
# Georgia                 84.419391
# Kentucky                84.343947
# Ohio                    84.238281
# Arizona                 84.178262
# Nebraska                84.143709
# Texas                   84.054117
# Tennessee               84.043385
# Indiana                 84.014258
# South Carolina          83.881572
# Arkansas                83.711530
# Oklahoma                83.703063
# Alabama                 83.627861
# Nevada                  83.606995
# Louisiana               83.350521
# West Virginia           83.329288
# Mississippi             83.020142

# %%
import missingno as msno
msno.matrix(health_inequality)
# Out:
# <AxesSubplot:>

# %%
health_corr = health_inequality.corr()

# top 10 variables with highest correlation to this variable
health_corr_sorted = health_corr.sort_values(by='le_agg_q1_F', ascending=False)[:25].reset_index()
#health_corr_sorted[['index','le_raceadj_q4_q2_M_diff']]
health_corr_sorted_asc = health_corr.sort_values(by='le_agg_q1_F', ascending=True)[:15].reset_index()

# %%
health_corr_sorted_top25 = list(health_corr_sorted['index'])
health_corr_sorted_top25 = [i for i in health_corr_sorted_top25 if "le_" not in i]
health_corr_sorted_top25.append("le_agg_q1_F")

# %%
health_corr_sorted_bottom25 = list(health_corr_sorted_asc['index'])
health_corr_sorted_bottom25 = [i for i in health_corr_sorted_bottom25 if "le_" not in i and 'sd' not in i]
health_corr_sorted_bottom25.append("le_agg_q1_F")

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(health_inequality[health_corr_sorted_bottom25].corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(health_inequality[health_corr_sorted_top25].corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(health_inequality[health_corr_sorted_bottom25].corr())
# Out:
# <AxesSubplot:>

# %%
health_inequality[health_corr_sorted_bottom25].corr()['le_raceadj_q2_M']
# Out:
# reimb_penroll_adj10      -0.478586
# amb_disch_per1000_10     -0.356087
# cs_frac_black            -0.295128
# puninsured2010           -0.264552
# cs_fam_wkidsinglemom     -0.251140
# cur_smoke_q3             -0.199842
# adjmortmeas_pnall30day   -0.192953
# bmi_obese_q2             -0.191648
# cs_race_theil_2000       -0.187763
# cur_smoke_q4             -0.187470
# cur_smoke_q2             -0.186506
# bmi_obese_q1             -0.177114
# crime_total              -0.176509
# poor_share               -0.170982
# cur_smoke_q1             -0.162985
# le_raceadj_q2_M           1.000000
# Name: le_raceadj_q2_M, dtype: float64

# %%
health_inequality[health_corr_sorted_top25].corr()['le_raceadj_q2_M']
# Out:
# scap_ski90pcm      0.387925
# mammogram_10       0.376594
# e_rank_b           0.339181
# med_prev_qual_z    0.333196
# diab_eyeexam_10    0.328003
# exercise_any_q1    0.310448
# exercise_any_q2    0.307201
# cs_educ_ba         0.263193
# exercise_any_q3    0.258475
# le_raceadj_q2_M    1.000000
# Name: le_raceadj_q2_M, dtype: float64

# %%
health_inequality['reimb_penroll_adj10'] = health_inequality['reimb_penroll_adj10']/1000

# %%
sns.set(rc={'figure.figsize':(9,6)}) 
g = sns.scatterplot(x="reimb_penroll_adj10",y="le_raceadj_q2_M", data=health_inequality)
plt.title("Male Race Adjusted Life Expectancy (Q2) vs. Medicare $ Per Enrollee")
# Out:
# Text(0.5, 1.0, 'Male Race Adjusted Life Expectancy (Q2) vs. Medicare $ Per Enrollee')

# %%
sns.set(rc={'figure.figsize':(9,6)}) 
g = sns.scatterplot(x="scap_ski90pcm",y="le_raceadj_q2_M", data=health_inequality)
plt.title("Male Race Adjusted Life Expectancy (Q2) vs. Social Capital Index")
# Out:
# Text(0.5, 1.0, 'Male Race Adjusted Life Expectancy (Q2) vs. Social Capital Index')

# %% [markdown]
# ## Ordinary Least Squares Regression with One Variable

# %%
def multivariate_ols(formulatxt, df):
    mod = smf.ols(formula=formulatxt , data=df, missing='drop')
    res = mod.fit()
    print(res.summary())
    return res

# %%
multivariate_ols("le_raceadj_q2_M ~ reimb_penroll_adj10", health_inequality)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        le_raceadj_q2_M   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     462.6
# Date:                Sun, 28 Feb 2021   Prob (F-statistic):           4.76e-90
# Time:                        09:55:41   Log-Likelihood:                -2457.2
# No. Observations:                1559   AIC:                             4918.
# Df Residuals:                    1557   BIC:                             4929.
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              84.5755      0.197    428.246      0.000      84.188      84.963
# reimb_penroll_adj10    -0.4488      0.021    -21.507      0.000      -0.490      -0.408
# ==============================================================================
# Omnibus:                       20.824   Durbin-Watson:                   1.675
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.088
# Skew:                           0.107   Prob(JB):                     1.08e-07
# Kurtosis:                       3.669   Cond. No.                         63.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Ordinary Least Squares Regression with >1 Variable

# %%
multivariate_ols("le_raceadj_q2_M ~ reimb_penroll_adj10 + scap_ski90pcm", health_inequality)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        le_raceadj_q2_M   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     302.1
# Date:                Sun, 28 Feb 2021   Prob (F-statistic):          1.80e-111
# Time:                        09:56:01   Log-Likelihood:                -2391.2
# No. Observations:                1550   AIC:                             4788.
# Df Residuals:                    1547   BIC:                             4805.
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              83.9134      0.206    407.741      0.000      83.510      84.317
# reimb_penroll_adj10    -0.3692      0.022    -16.745      0.000      -0.412      -0.326
# scap_ski90pcm           0.2842      0.028     10.218      0.000       0.230       0.339
# ==============================================================================
# Omnibus:                       24.347   Durbin-Watson:                   1.716
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.186
# Skew:                           0.196   Prob(JB):                     1.03e-07
# Kurtosis:                       3.587   Cond. No.                         68.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Logistic Regression with Dichotomous Variables

# %% [markdown]
# ### Generate dichotomous variables

# %%
def get_top_quantile_from_df(column_name, df):
    pandas_series = df['{0}'.format(column_name)]
    top_quantile = pandas_series.quantile(q=0.9)
    return top_quantile

# %%
def return_dichotomous(x, threshold):
    if x >= threshold:
        return 1
    else:
        return 0

# %%
def make_dichotomous_top_quantile(column_name, df):
    col_threshold = get_top_quantile_from_df(column_name, df)
    df['dichot_top_quant_{0}'.format(column_name)] = df['{0}'.format(column_name)].apply(lambda x: return_dichotomous(x, col_threshold))
    print('dichot_top_quant_{0} has been created'.format(column_name))

# %%
make_dichotomous_top_quantile('le_raceadj_q2_M', health_inequality)
# Out:
# dichot_top_quant_le_raceadj_q2_M has been created

# %%
make_dichotomous_top_quantile('reimb_penroll_adj10', health_inequality)
# Out:
# dichot_top_quant_reimb_penroll_adj10 has been created

# %%
make_dichotomous_top_quantile('puninsured2010', health_inequality)
# Out:
# dichot_top_quant_puninsured2010 has been created

# %%
## Examine value counts to see if roughly 10% of data has been labeled as being in the top quantile (10%)

# %%
health_inequality['dichot_top_quant_le_raceadj_q2_M'].value_counts()
# Out:
# 0    1403
# 1     156
# Name: dichot_top_quant_le_raceadj_q2_M, dtype: int64

# %%
health_inequality['dichot_top_quant_reimb_penroll_adj10'].value_counts()
# Out:
# 0    1403
# 1     156
# Name: dichot_top_quant_reimb_penroll_adj10, dtype: int64

# %% [markdown]
# ### Logistic Regression with One Binary Predictor Variable

# %%
# Inspired by the workbook here http://www.science.smith.edu/~jcrouser/SDS293/labs/lab4-py.html 

def logistic_regression(formulatxt, df):
    mod = smf.glm(formula=formulatxt , data=df, missing='drop', family=sm.families.Binomial())
    res = mod.fit()
    print(res.summary())
    print("\n\n\nOdds Ratio Metrics:")
    params = res.params
    conf = res.conf_int()
    conf['Odds Ratio'] = params
    conf.columns = ['5%', '95%', 'Odds Ratio']
    print(np.exp(conf))
    return res

# This function both PRINTS results and RETURNS an object that is the actual model itself (res)

# %%
res1 = logistic_regression('dichot_top_quant_le_raceadj_q2_M ~ dichot_top_quant_reimb_penroll_adj10', health_inequality)
# Out:
#                         Generalized Linear Model Regression Results
# ============================================================================================
# Dep. Variable:     dichot_top_quant_le_raceadj_q2_M   No. Observations:                 1559
# Model:                                          GLM   Df Residuals:                     1557
# Model Family:                              Binomial   Df Model:                            1
# Link Function:                                logit   Scale:                          1.0000
# Method:                                        IRLS   Log-Likelihood:                -496.17
# Date:                              Mon, 01 Mar 2021   Deviance:                       992.34
# Time:                                      12:08:11   Pearson chi2:                 1.56e+03
# No. Iterations:                                   7
# Covariance Type:                          nonrobust
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                               -2.0931      0.085    -24.508      0.000      -2.261      -1.926
# dichot_top_quant_reimb_penroll_adj10    -2.2507      0.717     -3.140      0.002      -3.656      -0.846
# ========================================================================================================
#
#
#
# Odds Ratio Metrics:
#                                             5%       95%  Odds Ratio
# Intercept                             0.104294  0.145766    0.123299
# dichot_top_quant_reimb_penroll_adj10  0.025848  0.429223    0.105330

# %%
# Access an object's specific attribute 
res1.params
# Out:
# Intercept                              -2.093146
# dichot_top_quant_reimb_penroll_adj10   -2.250660
# dtype: float64

# %%
# Access an object's specific attribute 
res1.pvalues
# Out:
# Intercept                               1.206459e-132
# dichot_top_quant_reimb_penroll_adj10     1.689951e-03
# dtype: float64

# %% [markdown]
# ### Logistic Regression with Two Predictor Variables

# %%
res2 = logistic_regression('dichot_top_quant_le_raceadj_q2_M ~ dichot_top_quant_reimb_penroll_adj10 + dichot_top_quant_puninsured2010', health_inequality)
# Out:
#                         Generalized Linear Model Regression Results
# ============================================================================================
# Dep. Variable:     dichot_top_quant_le_raceadj_q2_M   No. Observations:                 1559
# Model:                                          GLM   Df Residuals:                     1556
# Model Family:                              Binomial   Df Model:                            2
# Link Function:                                logit   Scale:                          1.0000
# Method:                                        IRLS   Log-Likelihood:                -495.59
# Date:                              Mon, 01 Mar 2021   Deviance:                       991.18
# Time:                                      11:20:25   Pearson chi2:                 1.55e+03
# No. Iterations:                                   7
# Covariance Type:                          nonrobust
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                               -2.0687      0.088    -23.543      0.000      -2.241      -1.896
# dichot_top_quant_reimb_penroll_adj10    -2.1703      0.720     -3.014      0.003      -3.582      -0.759
# dichot_top_quant_puninsured2010         -0.3702      0.359     -1.030      0.303      -1.074       0.334
# ========================================================================================================
#                                             5%       95%  Odds Ratio
# Intercept                             0.106361  0.150096    0.126350
# dichot_top_quant_reimb_penroll_adj10  0.027825  0.468203    0.114139
# dichot_top_quant_puninsured2010       0.341477  1.396649    0.690596

# %%
res2.params
# Out:
# Intercept                              -2.068698
# dichot_top_quant_reimb_penroll_adj10   -2.170341
# dichot_top_quant_puninsured2010        -0.370200
# dtype: float64

# %%
res2.scale
# Out:
# 1.0

# %% [markdown]
# ### Interpret the Probability from Logistic Regression Results

# %%
import math 

def interpret_log_params(coeff):
    probability = (1 / (1 + (math.e**(-1 * coeff))))
    return ("The probability predicted by the model is {0} percent".format(round(100*probability,2)))

# %%
# Probability predicted for overall counties to be in top quantile of male race adjusted life expectancy
interpret_log_params(-2.068698)
# Out:
# 'The probability predicted by the model is 11.22 percent'

# %%
# Probability predicted for overall counties to be in top quantile of male race adjusted life expectancy when a county is
# is in the top quantile of medicare reimbursement per person and  is in the top quantile of percent uninsured in 2010
interpret_log_params(-2.170341+-2.068698+-0.370200)
# Out:
# 'The probability predicted by the model is 0.99 percent'
