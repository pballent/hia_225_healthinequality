# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Health Inequality Dataset
#
# This data was taken from this study https://healthinequality.org/ that aimed to measure and shed light on racial and other inequalities in healthcare, and "uses big data to measure differences in life expectancy by income across areas and identify strategies to improve health outcomes for low-income Americans."
#
# Find the data dictionary for the inequality file [here](https://healthinequality.org/dl/health_ineq_online_table_11_readme.pdf)
#
# Find the data dictionary for the county file [here](https://healthinequality.org/dl/health_ineq_online_table_12_readme.pdf)

# %%
import pandas as pd
health_inequality = pd.read_csv("https://raw.githubusercontent.com/pballent/hia_255_healthinequality/main/health_inequality_dataset.csv")
health_inequality
# Out:
#         cty county_name  cty_pop2000     cz       cz_name  cz_pop2000  \
# 0      1001     Autauga        43671  11101    Montgomery      367927
# 1      1003     Baldwin       140415  11001        Mobile      599405
# 2      1005     Barbour        29038  10301       Eufaula       61458
# 3      1009      Blount        51024  10700    Birmingham     1038182
# 4      1015     Calhoun       112249   9600      LaGrange      457299
# ...     ...         ...          ...    ...           ...         ...
# 1554  56021     Laramie        81607  27702      Cheyenne       95526
# 1555  56025     Natrona        66533  34603        Casper       78585
# 1556  56029        Park        25786  34301          Cody       37247
# 1557  56033    Sheridan        26560  34304      Sheridan       46306
# 1558  56037  Sweetwater        37613  36404  Rock Springs       80730
#
#      statename  state_id stateabbrv  le_agg_q1_F  ...  cs_educ_ba  \
# ...

# %%
list(health_inequality.columns)
# Out:
# ['cty',
#  'county_name',
#  'cty_pop2000',
#  'cz',
#  'cz_name',
#  'cz_pop2000',
#  'statename',
#  'state_id',
#  'stateabbrv',
#  'le_agg_q1_F',
#  'le_raceadj_q1_F',
#  'le_agg_q2_F',
#  'le_raceadj_q2_F',
#  'le_agg_q3_F',
#  'le_raceadj_q3_F',
#  'le_agg_q4_F',
#  'le_raceadj_q4_F',
#  'le_agg_q1_M',
#  'le_raceadj_q1_M',
#  'le_agg_q2_M',
#  'le_raceadj_q2_M',
#  'le_agg_q3_M',
#  'le_raceadj_q3_M',
#  'le_agg_q4_M',
#  'le_raceadj_q4_M',
#  'sd_le_agg_q1_F',
#  'sd_le_raceadj_q1_F',
#  'sd_le_agg_q2_F',
#  'sd_le_raceadj_q2_F',
#  'sd_le_agg_q3_F',
#  'sd_le_raceadj_q3_F',
#  'sd_le_agg_q4_F',
#  'sd_le_raceadj_q4_F',
#  'sd_le_agg_q1_M',
#  'sd_le_raceadj_q1_M',
#  'sd_le_agg_q2_M',
#  'sd_le_raceadj_q2_M',
#  'sd_le_agg_q3_M',
#  'sd_le_raceadj_q3_M',
#  'sd_le_agg_q4_M',
#  'sd_le_raceadj_q4_M',
#  'count_q1_F',
#  'count_q2_F',
#  'count_q3_F',
#  'count_q4_F',
#  'count_q1_M',
#  'count_q2_M',
#  'count_q3_M',
#  'count_q4_M',
#  'exercise_any_q3',
# ...

# %%
health_inequality['le_agg_q4_q1_F_diff'] = health_inequality['le_agg_q1_F'] - health_inequality['le_agg_q4_F']

# %%
health_inequality['le_agg_q4_q1_F_diff'].describe()
# Out:
# count    1559.000000
# mean       -5.666102
# std         1.959490
# min       -11.815056
# 25%        -6.889244
# 50%        -5.799400
# 75%        -4.591706
# max         5.159027
# Name: le_agg_q4_q1_F_diff, dtype: float64

# %% [markdown]
# ## Steps to Explore and Measure Data
#
# 1. Examine the variables
# 2. Describe the dataset
# 3. Group the dataset in different ways (such as State)
# 4. Identify relationships (correlation) between variables
# 5. Graph some relationships between variables
# 6. Create one or more derived variables - suggested the difference between 1st income quartile life expectancy and 4th quartile life expectancy
# 6. Perform a linear regression predicting one variable on another

# %%
def mulivariate_ols(formulatxt, df):
    mod = smf.ols(formula=formulatxt , data=df, missing='drop')
    res = mod.fit()
    print(res.summary())
    return res

# %%
mulivariate_ols("le_agg_q4_q1_F_diff ~ gini99 + frac_middleclass + statename", health_inequality)
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     le_agg_q4_q1_F_diff   R-squared:                       0.106
# Model:                             OLS   Adj. R-squared:                  0.075
# Method:                  Least Squares   F-statistic:                     3.429
# Date:                 Wed, 17 Feb 2021   Prob (F-statistic):           1.20e-14
# Time:                         11:33:33   Log-Likelihood:                -3173.1
# No. Observations:                 1559   AIC:                             6452.
# Df Residuals:                     1506   BIC:                             6736.
# Df Model:                           52
# Covariance Type:             nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
mulivariate_ols("le_agg_q4_q1_F_diff ~ cur_smoke_q3 + gini99 + poor_share + inc_share_1perc + pop_density + cs_race_theil_2000 + frac_middleclass", health_inequality)
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     le_agg_q4_q1_F_diff   R-squared:                       0.051
# Model:                             OLS   Adj. R-squared:                  0.046
# Method:                  Least Squares   F-statistic:                     11.74
# Date:                 Wed, 17 Feb 2021   Prob (F-statistic):           1.26e-14
# Time:                         11:33:33   Log-Likelihood:                -3204.8
# No. Observations:                 1552   AIC:                             6426.
# Df Residuals:                     1544   BIC:                             6468.
# Df Model:                            7
# Covariance Type:             nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -4.4765      0.673     -6.650      0.000      -5.797      -3.156
# ...

# %%
health_corr = health_inequality.corr()

# top 10 variables with highest correlation to this variable
health_corr.sort_values(by='le_agg_q4_q1_F_diff', ascending=False)[:10]
# Out:
#                           cty  cty_pop2000        cz  cz_pop2000  state_id  \
# le_agg_q4_q1_F_diff -0.040391     0.091252  0.059241    0.103241 -0.040101
# le_agg_q1_F         -0.010140     0.187997  0.216929    0.195168 -0.009341
# le_raceadj_q1_F     -0.015029     0.082061 -0.054778    0.102571 -0.014191
# le_agg_q1_M          0.004951     0.231838  0.457018    0.286490  0.005917
# le_raceadj_q1_M     -0.005786     0.173164  0.273706    0.245447 -0.004668
# cs_born_foreign     -0.118028     0.526459  0.291463    0.501200 -0.118322
# cs_frac_hisp        -0.017852     0.240751  0.391796    0.187744 -0.018760
# sd_le_raceadj_q4_F   0.077814    -0.373843 -0.130873   -0.385617  0.077768
# unemp_rate           0.013731    -0.049849 -0.010943   -0.120412  0.013817
# sd_le_agg_q4_F       0.081761    -0.390437 -0.143469   -0.397766  0.081745
#
#                      le_agg_q1_F  le_raceadj_q1_F  le_agg_q2_F  \
# le_agg_q4_q1_F_diff     0.541964         0.479361     0.164827
# ...

# %%
# bottom 10 variables with highest correlation to this variable
health_corr.sort_values(by='le_agg_q4_q1_F_diff', ascending=True)[:10]
# Out:
#                          cty  cty_pop2000        cz  cz_pop2000  state_id  \
# le_raceadj_q4_F     0.048426    -0.003697  0.054146   -0.000671  0.048842
# le_agg_q4_F         0.037859     0.057555  0.119600    0.049925  0.038216
# cs_labforce         0.045147     0.095467  0.091136    0.181366  0.045318
# scap_ski90pcm       0.100063    -0.065094  0.202737   -0.093356  0.100774
# cur_smoke_q1        0.073440    -0.103253 -0.143059   -0.146684  0.073348
# primcarevis_10     -0.014755    -0.232479 -0.227215   -0.296214 -0.015352
# score_r             0.305666    -0.240731  0.090071   -0.182804  0.305648
# cs00_seg_inc_pov25 -0.081846     0.405842  0.082413    0.274025 -0.082235
# med_prev_qual_z     0.054757     0.002858 -0.066444    0.013319  0.055075
# mammogram_10       -0.003950    -0.001181 -0.068269    0.006526 -0.003059
#
#                     le_agg_q1_F  le_raceadj_q1_F  le_agg_q2_F  \
# le_raceadj_q4_F        0.165625         0.200952     0.211556
# ...

# %%
sns.heatmap(health_inequality.corr())
# Out:
# <AxesSubplot:>
